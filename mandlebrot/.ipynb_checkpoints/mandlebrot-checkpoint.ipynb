# %% [markdown]
# <div class="licence">
# <span>Licence CC BY-NC-ND</span>
# <span>Thierry Parmentelat &amp; Arnaud Legout</span>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib ipympl
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File C:\miniconda\Lib\site-packages\matplotlib\backends\registry.py:413, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     412 try:
# --> 413     return self.resolve_backend(gui_or_backend)
#     414 except Exception:  # KeyError ?
#
# File C:\miniconda\Lib\site-packages\matplotlib\backends\registry.py:375, in BackendRegistry.resolve_backend(self, backend)
#     374 if gui is None:
# --> 375     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     377 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'ipympl' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 get_ipython().run_line_magic('matplotlib', 'ipympl')
#
# File C:\miniconda\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File C:\miniconda\Lib\site-packages\IPython\core\magics\pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File C:\miniconda\Lib\site-packages\IPython\core\interactiveshell.py:3665, in InteractiveShell.enable_matplotlib(self, gui)
#    3662     import matplotlib_inline.backend_inline
#    3664 from IPython.core import pylabtools as pt
# -> 3665 gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3667 if gui != None:
#    3668     # If we have our first gui selection, store it
#    3669     if self.pylab_gui_select is None:
#
# File C:\miniconda\Lib\site-packages\IPython\core\pylabtools.py:349, in find_gui_and_backend(gui, gui_select)
#     347 else:
#     348     gui = _convert_gui_to_matplotlib(gui)
# --> 349     backend, gui = backend_registry.resolve_gui_or_backend(gui)
#     351 gui = _convert_gui_from_matplotlib(gui)
#     352 return gui, backend
#
# File C:\miniconda\Lib\site-packages\matplotlib\backends\registry.py:415, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     413     return self.resolve_backend(gui_or_backend)
#     414 except Exception:  # KeyError ?
# --> 415     raise RuntimeError(
#     416         f"'{gui_or_backend} is not a recognised GUI loop or backend name")
#
# RuntimeError: 'ipympl is not a recognised GUI loop or backend name

# %% [markdown]
# # l'ensemble de Mandelbrot
#
# il s'agit de calculer l'image de la convergence de mandelbrot:
#
# <img src="media/mandelbrot.svg">

# %% [markdown]
# ## comment ça marche ?

# %% [markdown]
# * dans l'espace complexe, on définit pour chaque $c\in\mathbb{C}$ la suite
#    * $z_0 = c$
#    * $z_{n+1} = z_n^2 + c$
# * on démontre que
#   * lorsque $|z_n|>2$, la suite diverge

# %% [markdown]
# il s'agit pour nous de
#
# * partir d'un pavé rectangulaire
#   par exemple sur la figure, on a pris l'habituel
#   $re \in [-2, 0.8]$ et  $im \in [-1.4, 1.4]$
# * découper ce pavé en un maillage de $w \times h$ points
#   (sur la figure, 1000 x 1000)
# * on se fixe un nombre maximal `max` d'itérations (disons 20)
#   * et pour chaque point du maillage, on va calculer si la suite diverge avant `max` itérations
# * c'est-à-dire plus spécifiquement on calcule un tableau `diverge` de la taille du maillage
#   * pour chaque point `z`, on calcule les `max` premiers termes de la suite
#   * et à la première itération `n` où la suite diverge (son module est supérieur à 2)
#     alors on affecte `diverge[z] = n`
# * on n'a plus qu'à afficher ensuite l'image obtenue avec `plt.imshow`

# %% [markdown]
# *indices*
#
# * pour fabriquer la grille des points de départ,
#   on pourra regarder `np.linspace` et `np.meshgrid`

# %%
# à vous de jouer

def mandelbrot(w, h):
    x = np.linspace(-2, 0.8, w)
    y = np.linspace(-1.4, 1.4, h)
    xv, yv = np.meshgrid(x, y)
    #plt.plot(xv, yv, marker='o', color='k', linestyle='none')
    #plt.show()
    max_ = 20
    diverge = np.zeros((w,h))
    
    #Faire tableau qui stocke les complexes associés aux points
    def complexify(x,y):
        return x+y*1j
    complexify = np.vectorize(complexify)
    C = complexify(xv,yv)
    
    #calcul du seuil de divergence pour chaque point
    def suite_div(c):
        zn = c
        n=0
        while (np.absolute(zn) <= 2) and (n <= max_) :
            zn = zn**2 + c
            n += 1
        return n
    suite_div = np.vectorize(suite_div)
    diverge = suite_div(C)

    #affichage
    plt.imshow(diverge)

mandelbrot(1000,1000)

# %% [markdown]
# ## v2
#
# * on peut passer en paramètre à la fonction
#   * le domaine en x et en y
#   * le nombre maximum d'itérations
# * on veut pouvoir produire une image (pour l'insérer dans l'énoncé par exemple)
#   * quels formats sont disponibles ?
#   * sauvez votre image dans un format vectoriel
#   * affichez cette depuis votre notebook

# %%
def mandelbrot_2(w, h, xmin, xmax, ymin, ymax, max_):
    
    x = np.linspace(xmin, xmax, w)
    y = np.linspace(ymin, ymax, h)
    xv, yv = np.meshgrid(x, y)
    #plt.plot(xv, yv, marker='o', color='k', linestyle='none')
    #plt.show()
    diverge = np.zeros((w,h))
    
    #Faire tableau qui stocke les complexes associés aux points
    def complexify(x,y):
        return x+y*1j
    complexify = np.vectorize(complexify)
    C = complexify(xv,yv)
    
    #calcul du seuil de divergence pour chaque point
    def suite_div(c):
        zn = c
        n=0
        while (np.absolute(zn) <= 2) and (n <= max_) :
            zn = zn**2 + c
            n += 1
        return n
    suite_div = np.vectorize(suite_div)
    diverge = suite_div(C)

    #sauvegarde image
    plt.imsave("media/mandelbrot_perso.svg", diverge)

mandelbrot_2(30, 30, -2, 0.8, -1.4, 1.4, 20)

# %%
from IPython.display import SVG, display
display(SVG('media/mandelbrot_perso.svg'))
